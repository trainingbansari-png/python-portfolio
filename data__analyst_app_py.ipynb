# %% [markdown]
# <a href="https://colab.research.google.com/github/trainingbansari-png/python-portfolio/blob/main/data__analyst_app_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install streamlit
import streamlit as st

st.set_page_config(page_title="Bansari Patel | Data Analyst", layout="wide")

st.title("👩‍💻 Bansari Patel")
st.subheader("Data Analyst | Python • SQL • ML")

st.write("---")

st.header("About Me")
st.write("""
I am a Data Analyst with internship experience at TEJASKP AI SOFTWARE.
I work on data cleaning, visualization, dashboards, and machine learning.
""")

st.header("Skills")
st.write("""
- Python (Pandas, NumPy)
- SQL
- Excel
- Power BI
- Machine Learning
""")

st.header("Projects")

st.subheader("Customer Segmentation")
st.write("""
- K-Means clustering
- Customer behavior analysis
- Business insights
""")

st.subheader("Jio Hotstar Data Analysis")
st.write("""
- Tools & Technologies:**
- Python (Pandas, Matplotlib)
- SQL (User activity & watch history analysis)
- Data Visualization
""")

st.header("Contact")
st.write("📧 Email: patelbansarijitendrakumar@gmail.com @email.com")
st.write("💻 GitHub: github.com/yourusername")

st.write("---")
st.write("© 2026 Bansari Patel")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 60.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 95.6 MB/s eta 0:00:00
# ...
# 2026-01-12 12:40:38.800 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-12 12:40:38.802 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-12 12:40:38.997
# ...
#   command:
#
#     streamlit run /usr/local/lib/python3.12/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2026-01-12 12:40:38.998 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-12 12:40:38.999 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
